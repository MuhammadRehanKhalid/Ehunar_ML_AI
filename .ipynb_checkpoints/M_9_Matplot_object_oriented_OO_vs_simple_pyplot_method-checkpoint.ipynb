# %% [markdown]
# # Matplotlib OO_method vs Pyplot_method

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib.image import imread
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %%
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
over_40 = df[df['age']>40]

# %%
over_40
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# 5     57    1   0     140   192    0        1       148     0      0.4    1
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %% [markdown]
# ## pyplot_method

# %%
# pyplot_method
over_40.plot(kind='scatter',
            x = 'age',
            y = 'chol',
            c = 'output')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %% [markdown]
# ## Object_Oriented Method

# %%
fig, ax = plt.subplots()
over_40.plot(kind = 'scatter',
            x = 'age',
            y = 'chol',
            c = 'output',
            ax = ax)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %% [markdown]
# # Entire life cycle ofobject oriented Plot

# %%
fig, ax = plt.subplots(figsize = (10,8))
scatter_plot = ax.scatter(x = df['age'],
                         y = df['chol'],
                         c = df['output'])
scatter_plot;

# %%
df['output'].dtype
# Out:
# dtype('int64')

# %%
fig, ax = plt.subplots(figsize = (10,8))
scatter_plot = ax.scatter(x = over_40['age'],
                         y = over_40['chol'],
                         c = over_40['output'])
# coustomization
ax.set(title='Suspectibility of Heart Disease',
      xlabel= 'Age of the Patient',
      ylabel= 'Blood Cholesterol Level')
# legend 
ax.legend(*scatter_plot.legend_elements(),title = 'output')
scatter_plot;

# %% [markdown]
# # Entire Life cycle of OO plot

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
# create plot canvas
fig, (plot1,plot2) = plt.subplots(ncols=1, nrows=2, figsize=(10,10), sharex=True)
# create first graph
scatter_plot = plot1.scatter(x = over_40['age'],
                         y = over_40['chol'],
                         c = over_40['output'])
# coustomize
plot1.set(title=' Heart diease Problem',
      # xlabel = 'age',
      ylabel = 'Cholesterol level')
plot1.legend(*scatter_plot.legend_elements(), title =  ' Survived or Not')
# 2nd Plot
# create first graph
scatter_plot1 = plot2.scatter(x = over_40['age'],
                         y = over_40['trtbps'],
                         c = over_40['output'])
# coustomize
plot2.set(title=' Heart diease Problem',
      xlabel = 'age',
      ylabel = 'Resting_blood_pressure')
plot2.legend(*scatter_plot1.legend_elements(), title =  ' Survived or Not')

scatter_plot;
scatter_plot1;

# %% [markdown]
# # Coustomization Part_2

# %%
# create plot canvas
fig, (plot1,plot2) = plt.subplots(ncols=1, nrows=2, figsize=(10,10), sharex=True)
# create first graph
scatter_plot = plot1.scatter(x = over_40['age'],
                         y = over_40['chol'],
                         c = over_40['output'])
# coustomize
plot1.set(title=' Heart diease Problem',
      # xlabel = 'age',
      ylabel = 'Cholesterol level')
plot1.legend(*scatter_plot.legend_elements(), title =  ' Survived or Not')
# 2nd Plot
# create first graph
scatter_plot1 = plot2.scatter(x = over_40['age'],
                         y = over_40['trtbps'],
                         c = over_40['output'])
# coustomize
plot2.set(title=' Heart diease Problem',
      xlabel = 'age',
      ylabel = 'Resting_blood_pressure')
plot2.legend(*scatter_plot1.legend_elements(), title =  ' Survived or Not')
plot1.axhline(y = over_40['chol'].mean(), linestyle = '--')
plot2.axhline(y = over_40['trtbps'].mean(), linestyle = '--')
scatter_plot;
scatter_plot1;

# %% [markdown]
# # Coustomization part_3

# %%
# create plot canvas
fig, (plot1,plot2) = plt.subplots(ncols=1, nrows=2, figsize=(10,10), sharex=True)
# create first graph
scatter_plot = plot1.scatter(x = over_40['age'],
                         y = over_40['chol'],
                         c = over_40['output'],
                            cmap='winter')
# coustomize
plot1.set(title=' Heart diease Problem',
      # xlabel = 'age',
      ylabel = 'Cholesterol level')
plot1.legend(*scatter_plot.legend_elements(), title =  ' Survived or Not')
# 2nd Plot
# create first graph
scatter_plot1 = plot2.scatter(x = over_40['age'],
                         y = over_40['trtbps'],
                         c = over_40['output'],
                             cmap='spring')
# coustomize
plot2.set(title=' Heart diease Problem',
      xlabel = 'age',
      ylabel = 'Resting_blood_pressure')
plot2.legend(*scatter_plot1.legend_elements(), title =  ' Survived or Not')
plot1.axhline(y = over_40['chol'].mean(), linestyle = '--')
plot2.axhline(y = over_40['trtbps'].mean(), linestyle = '--')
scatter_plot;
scatter_plot1;

# %% [markdown]
# ## figure styles

# %%
plt.style.available
plt.style.use('seaborn-v0_8-dark-palette')

# %%
# create plot canvas
fig, (plot1,plot2) = plt.subplots(ncols=1, nrows=2, figsize=(10,10), sharex=True)
# create first graph
scatter_plot = plot1.scatter(x = over_40['age'],
                         y = over_40['chol'],
                         c = over_40['output'],
                            cmap='winter')
# coustomize
plot1.set(title=' Heart diease Problem',
      # xlabel = 'age',
      ylabel = 'Cholesterol level')
plot1.legend(*scatter_plot.legend_elements(), title =  ' Survived or Not')
# 2nd Plot
# create first graph
scatter_plot1 = plot2.scatter(x = over_40['age'],
                         y = over_40['trtbps'],
                         c = over_40['output'],
                             cmap='spring')
# coustomize
plot2.set(title=' Heart diease Problem',
      xlabel = 'age',
      ylabel = 'Resting_blood_pressure')
plot2.legend(*scatter_plot1.legend_elements(), title =  ' Survived or Not')
plot1.axhline(y = over_40['chol'].mean(), linestyle = '--')
plot2.axhline(y = over_40['trtbps'].mean(), linestyle = '--')
plt.style.use( 'seaborn-v0_8-whitegrid')
scatter_plot;
scatter_plot1;

# %%
# naming entries figures
# create plot canvas
fig, (plot1,plot2) = plt.subplots(ncols=1, nrows=2, figsize=(10,10), sharex=True)
# create first graph
scatter_plot = plot1.scatter(x = over_40['age'],
                         y = over_40['chol'],
                         c = over_40['output'],
                            cmap='winter')
# coustomize
plot1.set(title=' Heart diease Problem',
      # xlabel = 'age',
      ylabel = 'Cholesterol level')
plot1.legend(*scatter_plot.legend_elements(), title =  ' Survived or Not')
# 2nd Plot
# create first graph
scatter_plot1 = plot2.scatter(x = over_40['age'],
                         y = over_40['trtbps'],
                         c = over_40['output'],
                             cmap='spring')
# coustomize
plot2.set(title=' Heart diease Problem',
      xlabel = 'age',
      ylabel = 'Resting_blood_pressure')
plot2.legend(*scatter_plot1.legend_elements(), title =  ' Survived or Not')
plot1.axhline(y = over_40['chol'].mean(), linestyle = '--')
plot2.axhline(y = over_40['trtbps'].mean(), linestyle = '--')
plt.style.use( 'seaborn-v0_8-whitegrid')
fig.suptitle('Patients_data', fontsize = 32, fontweight = 'bold')

scatter_plot;
scatter_plot1;

# save figure
